# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (15,10)

# %%
gt_data = np.load('gt_data.npy')

# %% [markdown]
# ### Plot VH Data Distribution

# %%
plt.hist(gt_data[0], bins=500)
plt.show()

# %% [markdown]
# ### Plot VV Data Distribution

# %%
plt.hist(gt_data[1], bins=500)
plt.show()
